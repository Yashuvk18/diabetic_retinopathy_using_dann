# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 MB 4.2 MB/s  0:00:19 eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 4.8 MB/s  0:00:006.8 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 5.8 MB/s  0:00:015.8 MB/s eta 0:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 5.0 MB/s  0:00:015.1 MB/s eta 0:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 4.8 MB/s  0:00:00m 5.0 MB/s eta 0:00:01
# ...
# Using cached fsspec-2026.2.0-py3-none-any.whl (202 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 5.5 MB/s  0:00:005.6 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 4.5 MB/s  0:00:04 eta 0:00:010:01:02
# ...

# %%
import pandas as pd
df = pd.read_csv("data/idrid/idrid_labels.csv")
print(df.columns.tolist())
print(df.head(1))
# Out:
# ['id_code', 'diagnosis', 'Risk of macular edema ', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11']
#      id_code  diagnosis  Risk of macular edema   Unnamed: 3  Unnamed: 4  \
# 0  IDRiD_001          3                       2         NaN         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# 0         NaN         NaN         NaN         NaN         NaN          NaN
#
#   Unnamed: 11
# 0         NaN

# %%
# !python -m src.train_baseline \
  --source-csv data/aptos/train.csv \
  --source-img-dir data/aptos/train_images \
  --source-image-col id_code \
  --source-label-col diagnosis \
  --source-default-ext .png \
  --target-csv data/idrid/idrid_labels.csv \
  --target-img-dir data/idrid/imagenes \
  --target-image-col id_code \
  --target-label-col diagnosis \
  --target-default-ext .jpg \
  --epochs 20 \
  --batch-size 16 \
  --output-dir outputs/baseline
# Out:
# Using device: mps
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /Users/aditya/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████████████████████████████████| 44.7M/44.7M [00:01<00:00, 29.2MB/s]
# Epoch 001 | train_acc=0.7337 | source_val_acc=0.7790 | target_acc=0.5297
# Epoch 002 | train_acc=0.8088 | source_val_acc=0.7885 | target_acc=0.5956
# Epoch 003 | train_acc=0.8310 | source_val_acc=0.8008 | target_acc=0.5604
# Epoch 004 | train_acc=0.8494 | source_val_acc=0.8022 | target_acc=0.5473
# Epoch 005 | train_acc=0.8658 | source_val_acc=0.8172 | target_acc=0.4593
# Epoch 006 | train_acc=0.8808 | source_val_acc=0.8063 | target_acc=0.5582
# Epoch 007 | train_acc=0.9013 | source_val_acc=0.8117 | target_acc=0.4725
# Epoch 008 | train_acc=0.9266 | source_val_acc=0.8008 | target_acc=0.5868
# Epoch 009 | train_acc=0.9382 | source_val_acc=0.8049 | target_acc=0.5626
# Epoch 010 | train_acc=0.9437 | source_val_acc=0.8090 | target_acc=0.5297
# ...
